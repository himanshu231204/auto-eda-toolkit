# %% [markdown]
# # 🚀 Auto EDA Toolkit - Complete Guide
# ## 90-95% EDA Automation for Any Dataset
#
# Bhai, is notebook mein tum dekh sakte ho ki kaise use karna hai!

# %% [markdown]
# ## 📦 Installation & Setup

# %%
# Install required packages (if not installed)
# !pip install pandas numpy matplotlib seaborn scipy scikit-learn

# %%
import sys
sys.path.append('../src')

from eda_engine import AutoEDA
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 🎯 Example 1: Basic Usage (Without Target)

# %%
# Load your dataset
df = pd.read_csv('../examples/sample_data.csv')

# Initialize AutoEDA
eda = AutoEDA(df)

# Run complete EDA - IT'S THAT SIMPLE!
report = eda.run_complete_eda()

# %% [markdown]
# ## 🎯 Example 2: With Target Column (Classification)

# %%
# For classification tasks
df = pd.read_csv('../examples/classification_data.csv')

# Specify target column
eda = AutoEDA(df, target_col='target')

# Run complete analysis
report = eda.run_complete_eda()

# %% [markdown]
# ## 🎯 Example 3: With Target Column (Regression)

# %%
# For regression tasks
df = pd.read_csv('../examples/regression_data.csv')

# Specify target column
eda = AutoEDA(df, target_col='price')

# Run complete analysis
report = eda.run_complete_eda()

# %% [markdown]
# ## 🔧 Example 4: Step-by-Step Analysis (Custom)

# %%
# If you want to run specific analyses only
df = pd.read_csv('../examples/sample_data.csv')
eda = AutoEDA(df, target_col='target')

# Identify column types
eda.identify_column_types()

# Basic info
eda.basic_info()

# Missing value analysis
eda.missing_value_analysis()

# Numerical analysis
eda.numerical_analysis()

# Categorical analysis
eda.categorical_analysis()

# Outlier detection
eda.outlier_detection()

# Target analysis
eda.target_analysis()

# Feature-target relationships
eda.feature_target_relationship()

# %% [markdown]
# ## 💾 Example 5: Generate & Save Report

# %%
# Generate and save report
report = eda.generate_report(save_path='../outputs/eda_report.txt')

# Access report dictionary
print(report.keys())

# %% [markdown]
# ## 🎨 What This Toolkit Covers:
#
# ### ✅ Basic Information
# - Dataset shape and size
# - Memory usage
# - Data types
# - First few rows preview
# - Duplicate detection
#
# ### ✅ Column Type Detection
# - Automatic identification of numerical columns
# - Automatic identification of categorical columns
# - DateTime column detection
#
# ### ✅ Missing Value Analysis
# - Missing count per column
# - Missing percentage
# - Visualization of missing values
#
# ### ✅ Numerical Analysis
# - Statistical summary (mean, median, std, etc.)
# - Distribution plots
# - Box plots for outlier detection
# - Skewness and kurtosis
# - Correlation matrix with heatmap
# - High correlation detection
#
# ### ✅ Categorical Analysis
# - Unique value counts
# - Most frequent values
# - Value distribution plots
# - Top categories visualization
#
# ### ✅ Outlier Detection
# - IQR method
# - Outlier counts and percentages
# - Upper and lower bounds
#
# ### ✅ Target Variable Analysis
# - Classification: class distribution, imbalance detection
# - Regression: distribution and statistics
#
# ### ✅ Feature-Target Relationships
# - Box plots for classification
# - Scatter plots for regression
# - Correlation analysis
#
# ### ✅ Report Generation
# - Comprehensive text report
# - Save to file
# - Structured report dictionary

# %% [markdown]
# ## 💡 Tips:
#
# 1. **For Large Datasets**: Consider sampling before EDA
#    ```python
#    df_sample = df.sample(n=10000, random_state=42)
#    eda = AutoEDA(df_sample)
#    ```
#
# 2. **Custom Categorical Threshold**: Modify in source if needed
#
# 3. **Multiple Target Analysis**: Run separately for each target
#
# 4. **Save Plots**: Use plt.savefig() after each plot
